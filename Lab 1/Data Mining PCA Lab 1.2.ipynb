# %%
#Dimensionality Reduction using Principle Component Analysis (PCA).

from sklearn import datasets
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as rnd

# %%
iris = datasets.load_iris()
R = np.array(iris.data)
print(R.shape)

df_iris = pd.DataFrame(iris.data,columns = iris.feature_names)
df_iris['target'] = pd.Series(iris.target)
df_iris.head(150)
# Out:
# (150, 4)
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# ...

# %%
#ignore target for now
X = df_iris.iloc[:,0:4].values
print(X)
print(np.mean(X))
print(np.std(X))
print(X.shape)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
X_std = StandardScaler().fit_transform(X)
print(np.mean(X_std))
print(np.std(X_std))
# Out:
# -1.4684549872375404e-15
# 1.0

# %%
#create 150*4 to 150*2 (150*4 => 150*3 => 150*2). 
#For 3D plot use 
#(PC1, PC2, PC3)
#(PC2, PC3, PC4)

#For 2D plot use 
#All possible combinations

# %%
A = rnd.rand(4,4)
print(A)
# Out:
# [[0.64883652 0.37874792 0.15461721 0.2159038 ]
#  [0.33117445 0.26325727 0.37714063 0.70664138]
#  [0.48770523 0.40077466 0.58994217 0.39143919]
#  [0.98578539 0.48279308 0.11572025 0.60547543]]

# %%
B = np.matmul(X,A)
print(B)
# Out:
# [[ 5.34812125  3.51065797  2.95760307  4.24346417]
#  [ 5.05276672  3.30327975  2.73810932  3.84696272]
#  [ 4.94046378  3.24010416  2.72361978  3.90596632]
#  [ 4.94000373  3.25605857  2.78843243  3.89199964]
#  [ 5.31635504  3.49910891  2.97985541  4.29253793]
#  [ 6.01871063  3.94637627  3.35497119  4.82941871]
#  [ 5.08916408  3.34323759  2.85415243  4.12539568]
#  [ 5.29889067  3.48653492  2.96342151  4.19035357]
#  [ 4.69523101  3.08758007  2.62308665  3.66834668]
#  [ 5.03607615  3.32140364  2.82324557  3.89622324]
#  [ 5.65777762  3.71701127  3.13841058  4.48870751]
#  [ 5.21789389  3.4508628   2.99149228  4.18631673]
#  [ 4.88930453  3.21712565  2.71107557  3.7648248 ]
#  [ 4.4185747   2.9075193   2.45678431  3.53944114]
#  [ 5.87035299  3.82725522  3.136417    4.66962968]
#  [ 6.28140777  4.11147435  3.47193823  5.1692227 ]
#  [ 5.82362854  3.78606641  3.11899432  4.67284303]
#  [ 5.44669979  3.55893728  2.9691751   4.30401171]
# ...

# %%
B = np.transpose(B)
covariance = np.cov(B)
print(covariance)
# Out:
# [[4.12389625 2.65919903 2.39583727 2.44732042]
#  [2.65919903 1.71559713 1.54756994 1.57878233]
#  [2.39583727 1.54756994 1.40134727 1.42409292]
#  [2.44732042 1.57878233 1.42409292 1.48241716]]

# %%
eigenvalue, eigenvector = np.linalg.eig(covariance)

print(eigenvalue)
print(eigenvector)
# Out:
# [8.69155429e+00 2.45498697e-02 7.06209536e-03 9.15663727e-05]
# [[-6.88474339e-01  3.06200433e-01 -5.06039731e-01 -4.19723921e-01]
#  [-4.44146776e-01  1.99389080e-01  4.22481256e-04  8.73485808e-01]
#  [-4.00659133e-01  1.86375949e-01  8.62485957e-01 -2.46686521e-01]
#  [-4.10132887e-01 -9.12002903e-01  6.44876460e-03 -3.64635548e-04]]

# %%
eigenvec_T = np.transpose(eigenvector)
Y = np.matmul(eigenvec_T,B)
Y = np.transpose(Y)
print(Y)
print(Y.shape)
# Out:
# [[-8.16666656e+00 -9.81241659e-01 -1.26622435e-01  9.06273661e-02]
#  [-7.62065571e+00 -7.92326179e-01 -1.69116148e-01  8.77435266e-02]
#  [-7.53367273e+00 -8.95821863e-01 -1.24429610e-01  8.32496271e-02]
#  [-7.56068169e+00 -8.67964424e-01 -6.83801331e-02  8.13953611e-02]
#  [-8.16870922e+00 -1.03387935e+00 -9.10435541e-02  8.83652121e-02]
#  [-9.22140141e+00 -1.14936181e+00 -1.19280122e-01  9.15196920e-02]
#  [-7.82414975e+00 -1.00551815e+00 -8.56366756e-02  7.86414908e-02]
#  [-8.10260720e+00 -9.51604519e-01 -9.70441811e-02  8.88035087e-02]
#  [-7.15935804e+00 -8.03351043e-01 -8.86372946e-02  7.78388722e-02]
#  [-7.67152832e+00 -8.22881517e-01 -8.69159058e-02  8.95599863e-02]
#  [-8.64453271e+00 -1.03524461e+00 -1.25708229e-01  9.62116564e-02]
#  [-8.04059051e+00 -9.74605072e-01 -3.18870465e-02  8.47174973e-02]
#  [-7.42533234e+00 -7.89684976e-01 -1.10280098e-01  8.77969461e-02]
#  [-6.76941490e+00 -8.37398004e-01 -9.29789884e-02  7.77491650e-02]
# ...

# %%
covariance_2 = np.cov(np.transpose(Y))
print(covariance_2)
# Out:
# [[ 8.69155429e+00 -6.39848263e-16  1.28750902e-15  6.11922157e-16]
#  [-6.39848263e-16  2.45498697e-02 -2.46517414e-16 -4.17129173e-16]
#  [ 1.28750902e-15 -2.46517414e-16  7.06209536e-03  3.49630535e-16]
#  [ 6.11922157e-16 -4.17129173e-16  3.49630535e-16  9.15663727e-05]]

# %%
sorted_eign = np.sort(eigenvalue)[::-1]
print(sorted_eign/np.sum(sorted_eign)*100)
# Out:
# [9.96365632e+01 2.81430059e-01 8.09570863e-02 1.04968092e-03]

# %%
new_eigenvector = eigenvec_T[0:3]
print(new_eigenvector.shape)
# Out:
# (3, 4)

# %%
Y = np.transpose(Y)
X = np.matmul(new_eigenvector,Y)
new_150_by_3 = np.transpose(X)
print(new_150_by_3.shape)
# Out:
# (150, 3)

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(X[:,0], X[:,1], X[:,2])
ax.view_init(20,20)
plt.show()

# %%
C = rnd.rand(3,3)
print(C)
# Out:
# [[0.68174851 0.09013158 0.25535978]
#  [0.38748741 0.296116   0.80315499]
#  [0.01423704 0.50045267 0.77797439]]

# %%
D = np.matmul(new_150_by_3,C)
print(D)
print(D.shape)
# Out:
# [[3.11085803 1.7310256  2.42992328]
#  [2.88266435 1.59372953 2.23401412]
#  [2.86928662 1.59370694 2.23684073]
#  [2.86327081 1.62613487 2.28869801]
#  [3.11818023 1.74719564 2.45554883]
#  [3.52433707 1.96775868 2.76782349]
#  [2.99359269 1.67573291 2.35737094]
#  [3.07682007 1.73109085 2.43335608]
#  [2.71112846 1.52917734 2.15029019]
#  [2.8911071  1.64106644 2.30657561]
#  [3.29036933 1.83604683 2.57801416]
#  [3.05010432 1.74732614 2.46241443]
#  [2.80102484 1.57640633 2.21315947]
#  [2.58011365 1.43899983 2.01947074]
#  [3.41985214 1.84391476 2.57739883]
#  [3.72385539 2.04839308 2.87656677]
#  [3.41224847 1.83830796 2.5741256 ]
#  [3.16512859 1.74028511 2.44109487]
#  [3.51748219 1.95845651 2.75039249]
#  [3.2972242  1.845349   2.59544516]
#  [3.24234017 1.82807098 2.56893728]
#  [3.31680361 1.83037477 2.57130814]
#  [2.89661584 1.58549016 2.22311869]
#  [3.28835385 1.8074247  2.53809423]
#  [3.13417077 1.84441418 2.60768784]
#  [2.9660776  1.66651858 2.34054612]
# ...

# %%
E = np.transpose(D)
covariance_second = np.cov(E)
print(covariance_second)
# Out:
# [[1.11499602 0.69811619 1.00541862]
#  [0.69811619 0.44002144 0.63406506]
#  [1.00541862 0.63406506 0.91373646]]

# %%
eigenvalue_second, eigenvector_second = np.linalg.eig(covariance_second)

print(eigenvalue_second)
print(eigenvector_second)
# Out:
# [2.46419788e+00 4.55165228e-03 4.37858909e-06]
# [[ 0.67191387  0.73947185  0.04139013]
#  [ 0.42232122 -0.33663041 -0.84162031]
#  [ 0.60842135 -0.58297629  0.53848129]]

# %%
eigenvec_T_2 = np.transpose(eigenvector_second)
print(eigenvec_T_2.shape)
Z = np.matmul(D,eigenvec_T_2)
print(Z)
print(Z.shape)
# Out:
# (3, 3)
# [[ 3.47084818 -1.31400729  2.19203381]
#  [ 3.2078864  -1.19927916  2.02774283]
#  [ 3.19899801 -1.20730019  2.02113878]
#  [ 3.22108182 -1.26440116  2.02649809]
#  [ 3.48878601 -1.33792528  2.20086092]
#  [ 3.93771366 -1.50346155  2.48754645]
#  [ 3.34816564 -1.28385621  2.11385332]
#  [ 3.44816794 -1.33129332  2.17313485]
#  [ 3.04142918 -1.17952842  1.91592536]
#  [ 3.25156684 -1.27271788  2.04435629]
#  [ 3.67525405 -1.39818549  2.3197716 ]
#  [ 3.44342553 -1.37249734  2.163063  ]
#  [ 3.13935849 -1.21037404  1.97694079]
#  [ 2.88130015 -1.09440195  1.81834068]
#  [ 3.768048   -1.34563286  2.39363354]
#  [ 4.13590055 -1.53786528  2.62048594]
#  [ 3.75865743 -1.34420182  2.39051336]
#  [ 3.51462286 -1.30360695  2.22567079]
#  [ 3.92550761 -1.48855483  2.47941248]
#  [ 3.6874601  -1.41309221  2.32790557]
#  [ 3.63670898 -1.40814502  2.29031163]
#  [ 3.68854373 -1.37946842  2.33555038]
#  [ 3.21071685 -1.18144371  2.03516759]
#  [ 3.65108228 -1.35580416  2.31373522]
# ...

# %%
covariance_3 = np.cov(np.transpose(Z))
print(covariance_3)
# Out:
# [[ 1.53403257 -0.71928894  0.95339552]
#  [-0.71928894  0.34201386 -0.44613965]
#  [ 0.95339552 -0.44613965  0.59270749]]

# %%
sorted_eign_second = np.sort(eigenvalue_second)[::-1]
print(sorted_eign_second/np.sum(sorted_eign_second)*100)
# Out:
# [9.98154522e+01 1.84370433e-01 1.77360290e-04]

# %%
new_eigenvector_2 = eigenvec_T_2[0:2]
print(new_eigenvector_2.shape)
# Out:
# (2, 3)

# %%
D = np.transpose(D)
X_2 = np.matmul(new_eigenvector_2,D)
new_150_by_2 = np.transpose(X_2)
print(new_150_by_2.shape)
print(new_150_by_2)
# Out:
# (150, 2)
# [[4.2996947  0.30108842]
#  [3.96918984 0.29277406]
#  [3.96191139 0.28124135]
#  [4.00311536 0.23564505]
#  [4.32703467 0.28612057]
#  [4.8830801  0.33016517]
#  [4.15340882 0.2752835 ]
#  [4.27894027 0.27389511]
#  [3.77573131 0.23646738]
#  [4.03900198 0.24078055]
#  [4.55476518 0.31214517]
#  [4.28552582 0.23173395]
#  [3.89433076 0.25039322]
#  [3.57002342 0.24620675]
#  [4.64471489 0.4056042 ]
#  [5.11735458 0.38716461]
#  [4.6352465  0.40377713]
#  [4.34686736 0.33159017]
#  [4.86394032 0.33838944]
#  [4.57390496 0.3039209 ]
#  [4.51360278 0.28460548]
#  [4.56605122 0.33751141]
#  [3.96845537 0.31221619]
#  [4.51703508 0.34356223]
#  [4.47140102 0.17652498]
#  [4.12079307 0.26784716]
#  [4.43524399 0.31649562]
#  [4.38933953 0.29456452]
#  [4.27235473 0.31605627]
#  [4.14778659 0.22603238]
#  [4.12044662 0.24100023]
#  [4.4840313  0.38241496]
#  [4.67232526 0.2455302 ]
#  [4.79562521 0.32698344]
#  [4.08617464 0.27128231]
#  [3.98301227 0.3352816 ]
# ...

# %%
plt.scatter(new_150_by_2[:,0],new_150_by_2[:,1])
plt.axis('equal')
plt.grid(True)
